# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import requests
from datetime import datetime
from citipy import citipy
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of random latitude and longitude combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
#add lats and longs to a list
coordinates = list(lat_lngs)

# %%
#create list for holding cities
cities = []

#Identify nearest city for each land and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if city is unique, add to cities list
    if city not in cities:
        cities.append(city)

#print city count to confirm sufficient count
len(cities)
# Out:
# 750

# %%
#create empty list to hold weather data
city_data = []
#print beginging of the logging
print("Begining Data Retrieval")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#loop through all the cities in list
for i, city in enumerate(cities):
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log url, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #add 1 to the record count
    record_count += 1

# Run an API request for each of the cities.
    try: 
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
     # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"] 
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
         # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Begining Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gobabis
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | san patricio
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | banjarmasin
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | kayes
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | fairhope
# Processing Record 14 of Set 1 | vega de alatorre
# Processing Record 15 of Set 1 | bathsheba
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 1 | barcelona
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | kahului
# Processing Record 25 of Set 1 | asau
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | fare
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | camopi
# Processing Record 34 of Set 1 | meulaboh
# Processing Record 35 of Set 1 | coahuayana
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | haines junction
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | plerin
# Processing Record 41 of Set 1 | broome
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | balkhash
# Processing Record 44 of Set 1 | port hardy
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | kupang
# Processing Record 49 of Set 1 | fairview
# Processing Record 50 of Set 1 | vaitape
# Processing Record 1 of Set 2 | komsomolskiy
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | urengoy
# Processing Record 5 of Set 2 | pran buri
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | praia da vitoria
# Processing Record 8 of Set 2 | woodward
# Processing Record 9 of Set 2 | lata
# Processing Record 10 of Set 2 | ust-tsilma
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | vitim
# Processing Record 13 of Set 2 | pamanukan
# Processing Record 14 of Set 2 | kijang
# Processing Record 15 of Set 2 | saint simons
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | ponta do sol
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | oktyabrskoye
# Processing Record 21 of Set 2 | ahipara
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | verkhoyansk
# Processing Record 24 of Set 2 | mayo
# Processing Record 25 of Set 2 | barras
# Processing Record 26 of Set 2 | high level
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | tashara
# Processing Record 31 of Set 2 | iralaya
# Processing Record 32 of Set 2 | pastavy
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | zhigansk
# Processing Record 36 of Set 2 | egvekinot
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | paamiut
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | belgrade
# Processing Record 41 of Set 2 | smolenskaya
# Processing Record 42 of Set 2 | elizabeth city
# Processing Record 43 of Set 2 | albertville
# Processing Record 44 of Set 2 | ulladulla
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | cabedelo
# Processing Record 1 of Set 3 | lahij
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | dibaya
# City not found. Skipping...
# Processing Record 4 of Set 3 | geylegphug
# City not found. Skipping...
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | avera
# Processing Record 7 of Set 3 | vila velha
# Processing Record 8 of Set 3 | george town
# Processing Record 9 of Set 3 | suntar
# Processing Record 10 of Set 3 | tazovskiy
# Processing Record 11 of Set 3 | chumikan
# Processing Record 12 of Set 3 | parit raja
# Processing Record 13 of Set 3 | mitchell
# Processing Record 14 of Set 3 | loei
# Processing Record 15 of Set 3 | kidodi
# Processing Record 16 of Set 3 | palmer
# Processing Record 17 of Set 3 | belaya gora
# Processing Record 18 of Set 3 | czluchow
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | ponferrada
# Processing Record 24 of Set 3 | shagamu
# Processing Record 25 of Set 3 | te anau
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | sinjar
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | salta
# Processing Record 30 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 3 | lagoa
# Processing Record 32 of Set 3 | neyshabur
# Processing Record 33 of Set 3 | ekibastuz
# Processing Record 34 of Set 3 | honavar
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | shelburne
# Processing Record 37 of Set 3 | aborlan
# Processing Record 38 of Set 3 | eureka
# Processing Record 39 of Set 3 | kirakira
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | bonthe
# Processing Record 42 of Set 3 | hamilton
# Processing Record 43 of Set 3 | tessalit
# Processing Record 44 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 3 | saint-nazaire
# Processing Record 46 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | vanavara
# Processing Record 49 of Set 3 | gimli
# Processing Record 50 of Set 3 | corrales
# Processing Record 1 of Set 4 | sechura
# Processing Record 2 of Set 4 | talnakh
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | husavik
# Processing Record 5 of Set 4 | tunceli
# Processing Record 6 of Set 4 | victoria
# Processing Record 7 of Set 4 | dourados
# Processing Record 8 of Set 4 | castro
# Processing Record 9 of Set 4 | wewak
# Processing Record 10 of Set 4 | kavieng
# Processing Record 11 of Set 4 | saint-augustin
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | berlevag
# Processing Record 14 of Set 4 | grindavik
# Processing Record 15 of Set 4 | puerto quijarro
# Processing Record 16 of Set 4 | juneau
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | aksu
# Processing Record 19 of Set 4 | bredasdorp
# Processing Record 20 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | imeni poliny osipenko
# Processing Record 24 of Set 4 | port augusta
# Processing Record 25 of Set 4 | souillac
# Processing Record 26 of Set 4 | sur
# Processing Record 27 of Set 4 | atar
# Processing Record 28 of Set 4 | whitstable
# Processing Record 29 of Set 4 | kailua
# Processing Record 30 of Set 4 | nouadhibou
# Processing Record 31 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 4 | yellowknife
# Processing Record 33 of Set 4 | poum
# Processing Record 34 of Set 4 | moree
# Processing Record 35 of Set 4 | mar del plata
# Processing Record 36 of Set 4 | abha
# Processing Record 37 of Set 4 | varhaug
# Processing Record 38 of Set 4 | ilulissat
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | nishihara
# Processing Record 41 of Set 4 | mahebourg
# Processing Record 42 of Set 4 | puerto ayora
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | nelson bay
# Processing Record 46 of Set 4 | luderitz
# Processing Record 47 of Set 4 | erzin
# Processing Record 48 of Set 4 | diffa
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | ixtapa
# Processing Record 2 of Set 5 | isla mujeres
# Processing Record 3 of Set 5 | panaba
# Processing Record 4 of Set 5 | nioro
# Processing Record 5 of Set 5 | katsuura
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | abu samrah
# Processing Record 8 of Set 5 | raga
# Processing Record 9 of Set 5 | ishurdi
# Processing Record 10 of Set 5 | hella
# Processing Record 11 of Set 5 | aranos
# Processing Record 12 of Set 5 | quang ngai
# Processing Record 13 of Set 5 | deputatskiy
# Processing Record 14 of Set 5 | vila
# Processing Record 15 of Set 5 | issia
# Processing Record 16 of Set 5 | ugu
# Processing Record 17 of Set 5 | lasa
# Processing Record 18 of Set 5 | port hedland
# Processing Record 19 of Set 5 | huangnihe
# Processing Record 20 of Set 5 | isangel
# Processing Record 21 of Set 5 | krasnoselkup
# Processing Record 22 of Set 5 | cartagena
# Processing Record 23 of Set 5 | waki
# Processing Record 24 of Set 5 | yuzhno-kurilsk
# Processing Record 25 of Set 5 | makurdi
# Processing Record 26 of Set 5 | ocos
# Processing Record 27 of Set 5 | bilma
# Processing Record 28 of Set 5 | shingu
# Processing Record 29 of Set 5 | kikwit
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | hermanus
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | opuwo
# Processing Record 34 of Set 5 | pringsewu
# Processing Record 35 of Set 5 | naples park
# Processing Record 36 of Set 5 | olga
# Processing Record 37 of Set 5 | coruripe
# Processing Record 38 of Set 5 | cleveland
# Processing Record 39 of Set 5 | ostrovnoy
# Processing Record 40 of Set 5 | akhisar
# Processing Record 41 of Set 5 | itarema
# Processing Record 42 of Set 5 | gazojak
# Processing Record 43 of Set 5 | port moresby
# Processing Record 44 of Set 5 | dujuma
# City not found. Skipping...
# Processing Record 45 of Set 5 | oranjemund
# Processing Record 46 of Set 5 | portland
# Processing Record 47 of Set 5 | severo-kurilsk
# Processing Record 48 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 50 of Set 5 | yarim
# Processing Record 1 of Set 6 | puri
# Processing Record 2 of Set 6 | okhotsk
# Processing Record 3 of Set 6 | san luis
# Processing Record 4 of Set 6 | boa vista
# Processing Record 5 of Set 6 | barrow
# Processing Record 6 of Set 6 | garissa
# Processing Record 7 of Set 6 | namibe
# Processing Record 8 of Set 6 | bajil
# Processing Record 9 of Set 6 | taltal
# Processing Record 10 of Set 6 | salinopolis
# Processing Record 11 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 6 | dunedin
# Processing Record 13 of Set 6 | iguape
# Processing Record 14 of Set 6 | torres
# Processing Record 15 of Set 6 | hammerfest
# Processing Record 16 of Set 6 | norman wells
# Processing Record 17 of Set 6 | bluff
# Processing Record 18 of Set 6 | sao joao da barra
# Processing Record 19 of Set 6 | biak
# Processing Record 20 of Set 6 | levashovo
# Processing Record 21 of Set 6 | sasaram
# Processing Record 22 of Set 6 | sesheke
# Processing Record 23 of Set 6 | cachoeira do sul
# Processing Record 24 of Set 6 | ouricuri
# Processing Record 25 of Set 6 | yecla
# Processing Record 26 of Set 6 | mount isa
# Processing Record 27 of Set 6 | santa maria
# Processing Record 28 of Set 6 | tarragona
# Processing Record 29 of Set 6 | plainview
# Processing Record 30 of Set 6 | neuquen
# Processing Record 31 of Set 6 | dalen
# Processing Record 32 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 6 | melbu
# Processing Record 34 of Set 6 | villa carlos paz
# Processing Record 35 of Set 6 | henties bay
# Processing Record 36 of Set 6 | snezhnogorsk
# Processing Record 37 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 6 | mweka
# Processing Record 39 of Set 6 | oyama
# Processing Record 40 of Set 6 | viedma
# Processing Record 41 of Set 6 | la ronge
# Processing Record 42 of Set 6 | boyolangu
# Processing Record 43 of Set 6 | los alamos
# Processing Record 44 of Set 6 | marawi
# Processing Record 45 of Set 6 | kaka
# Processing Record 46 of Set 6 | sonder bjert
# Processing Record 47 of Set 6 | anadyr
# Processing Record 48 of Set 6 | ibra
# Processing Record 49 of Set 6 | guilford
# Processing Record 50 of Set 6 | fairbanks
# Processing Record 1 of Set 7 | elburg
# Processing Record 2 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 3 of Set 7 | kuragino
# Processing Record 4 of Set 7 | limon
# Processing Record 5 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 7 | pangody
# Processing Record 7 of Set 7 | saint-pierre
# Processing Record 8 of Set 7 | cockburn town
# Processing Record 9 of Set 7 | gladstone
# Processing Record 10 of Set 7 | khandbari
# Processing Record 11 of Set 7 | mehamn
# Processing Record 12 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 13 of Set 7 | richards bay
# Processing Record 14 of Set 7 | sao joaquim
# Processing Record 15 of Set 7 | caravelas
# Processing Record 16 of Set 7 | gorontalo
# Processing Record 17 of Set 7 | balsas
# Processing Record 18 of Set 7 | fort nelson
# Processing Record 19 of Set 7 | bay saint louis
# Processing Record 20 of Set 7 | ambovombe
# Processing Record 21 of Set 7 | kirovskiy
# Processing Record 22 of Set 7 | aswan
# Processing Record 23 of Set 7 | ullapool
# Processing Record 24 of Set 7 | jinchang
# Processing Record 25 of Set 7 | xichang
# Processing Record 26 of Set 7 | coquimbo
# Processing Record 27 of Set 7 | ambon
# Processing Record 28 of Set 7 | mersing
# Processing Record 29 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 7 | bengkulu
# Processing Record 31 of Set 7 | bafq
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | sayyan
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | carutapera
# Processing Record 36 of Set 7 | hualmay
# Processing Record 37 of Set 7 | bonavista
# Processing Record 38 of Set 7 | sorland
# Processing Record 39 of Set 7 | torbay
# Processing Record 40 of Set 7 | kokopo
# Processing Record 41 of Set 7 | gamba
# Processing Record 42 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 44 of Set 7 | gat
# Processing Record 45 of Set 7 | port hawkesbury
# Processing Record 46 of Set 7 | swift current
# Processing Record 47 of Set 7 | oktyabrskiy
# Processing Record 48 of Set 7 | aztec
# Processing Record 49 of Set 7 | banda aceh
# Processing Record 50 of Set 7 | mecca
# Processing Record 1 of Set 8 | trinidad
# Processing Record 2 of Set 8 | wuning
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | sturgis
# Processing Record 5 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 8 | sitka
# Processing Record 8 of Set 8 | ulkan
# Processing Record 9 of Set 8 | cap malheureux
# Processing Record 10 of Set 8 | teguise
# Processing Record 11 of Set 8 | russell
# Processing Record 12 of Set 8 | izhma
# Processing Record 13 of Set 8 | winnemucca
# Processing Record 14 of Set 8 | urumqi
# Processing Record 15 of Set 8 | ko samui
# Processing Record 16 of Set 8 | nederland
# Processing Record 17 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 8 | freeport
# Processing Record 19 of Set 8 | koslan
# Processing Record 20 of Set 8 | stonewall
# Processing Record 21 of Set 8 | vangaindrano
# Processing Record 22 of Set 8 | awjilah
# Processing Record 23 of Set 8 | yerbogachen
# Processing Record 24 of Set 8 | tanout
# Processing Record 25 of Set 8 | langsa
# Processing Record 26 of Set 8 | paris
# Processing Record 27 of Set 8 | port keats
# Processing Record 28 of Set 8 | san quintin
# Processing Record 29 of Set 8 | yulara
# Processing Record 30 of Set 8 | alofi
# Processing Record 31 of Set 8 | lima
# Processing Record 32 of Set 8 | aliwal north
# Processing Record 33 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 8 | anloga
# Processing Record 35 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 8 | langfang
# Processing Record 37 of Set 8 | guadalupe y calvo
# Processing Record 38 of Set 8 | songjianghe
# Processing Record 39 of Set 8 | alice springs
# Processing Record 40 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 42 of Set 8 | boende
# Processing Record 43 of Set 8 | manaure
# Processing Record 44 of Set 8 | pisco
# Processing Record 45 of Set 8 | taksimo
# Processing Record 46 of Set 8 | sept-iles
# Processing Record 47 of Set 8 | betamcherla
# Processing Record 48 of Set 8 | mareeba
# Processing Record 49 of Set 8 | doha
# Processing Record 50 of Set 8 | cayenne
# Processing Record 1 of Set 9 | vila franca do campo
# Processing Record 2 of Set 9 | lunglei
# Processing Record 3 of Set 9 | ozinki
# Processing Record 4 of Set 9 | nchelenge
# Processing Record 5 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 9 | uchiza
# Processing Record 8 of Set 9 | anton lizardo
# Processing Record 9 of Set 9 | port blair
# Processing Record 10 of Set 9 | baykit
# Processing Record 11 of Set 9 | omsukchan
# Processing Record 12 of Set 9 | mugumu
# Processing Record 13 of Set 9 | hajnowka
# Processing Record 14 of Set 9 | derzhavinsk
# Processing Record 15 of Set 9 | sinfra
# Processing Record 16 of Set 9 | kaffrine
# Processing Record 17 of Set 9 | sangar
# Processing Record 18 of Set 9 | eshowe
# Processing Record 19 of Set 9 | santa cruz de tenerife
# Processing Record 20 of Set 9 | touros
# Processing Record 21 of Set 9 | zyryanka
# Processing Record 22 of Set 9 | alta floresta
# Processing Record 23 of Set 9 | lavrentiya
# Processing Record 24 of Set 9 | pandan
# Processing Record 25 of Set 9 | jaguarao
# Processing Record 26 of Set 9 | tamluk
# Processing Record 27 of Set 9 | mackay
# Processing Record 28 of Set 9 | osuna
# Processing Record 29 of Set 9 | maine-soroa
# Processing Record 30 of Set 9 | hami
# Processing Record 31 of Set 9 | soyo
# Processing Record 32 of Set 9 | kagalnitskaya
# Processing Record 33 of Set 9 | muros
# Processing Record 34 of Set 9 | clyde river
# Processing Record 35 of Set 9 | oussouye
# Processing Record 36 of Set 9 | zhigalovo
# Processing Record 37 of Set 9 | victor harbor
# Processing Record 38 of Set 9 | puerto narino
# Processing Record 39 of Set 9 | taonan
# Processing Record 40 of Set 9 | beaufort
# Processing Record 41 of Set 9 | acapulco
# Processing Record 42 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 43 of Set 9 | kerema
# Processing Record 44 of Set 9 | svetlaya
# Processing Record 45 of Set 9 | tuatapere
# Processing Record 46 of Set 9 | esperance
# Processing Record 47 of Set 9 | bontang
# Processing Record 48 of Set 9 | selenice
# Processing Record 49 of Set 9 | kutum
# Processing Record 50 of Set 9 | aberdeen
# Processing Record 1 of Set 10 | barguzin
# Processing Record 2 of Set 10 | shimoda
# Processing Record 3 of Set 10 | dongsheng
# Processing Record 4 of Set 10 | adrar
# Processing Record 5 of Set 10 | smithers
# Processing Record 6 of Set 10 | aitape
# Processing Record 7 of Set 10 | gambela
# Processing Record 8 of Set 10 | fuxin
# Processing Record 9 of Set 10 | canutama
# Processing Record 10 of Set 10 | ler
# Processing Record 11 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 10 | upata
# Processing Record 13 of Set 10 | brae
# Processing Record 14 of Set 10 | chifeng
# Processing Record 15 of Set 10 | rio gallegos
# Processing Record 16 of Set 10 | kununurra
# Processing Record 17 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 10 | sibolga
# Processing Record 19 of Set 10 | chimbote
# Processing Record 20 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 10 | korla
# Processing Record 22 of Set 10 | keti bandar
# Processing Record 23 of Set 10 | helena
# Processing Record 24 of Set 10 | inirida
# Processing Record 25 of Set 10 | korsor
# Processing Record 26 of Set 10 | rafsanjan
# Processing Record 27 of Set 10 | lompoc
# Processing Record 28 of Set 10 | gidam
# Processing Record 29 of Set 10 | hohhot
# Processing Record 30 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 31 of Set 10 | malartic
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | rayong
# Processing Record 34 of Set 10 | botucatu
# Processing Record 35 of Set 10 | rawlins
# Processing Record 36 of Set 10 | guerrero negro
# Processing Record 37 of Set 10 | emet
# Processing Record 38 of Set 10 | staraya toropa
# Processing Record 39 of Set 10 | nhamunda
# Processing Record 40 of Set 10 | birakan
# Processing Record 41 of Set 10 | axim
# Processing Record 42 of Set 10 | djibo
# Processing Record 43 of Set 10 | bitung
# Processing Record 44 of Set 10 | ossora
# Processing Record 45 of Set 10 | taoudenni
# Processing Record 46 of Set 10 | gualaquiza
# Processing Record 47 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 48 of Set 10 | mandalgovi
# Processing Record 49 of Set 10 | ekhabi
# Processing Record 50 of Set 10 | nadvoitsy
# Processing Record 1 of Set 11 | wad madani
# Processing Record 2 of Set 11 | tres arroyos
# Processing Record 3 of Set 11 | puerto madryn
# Processing Record 4 of Set 11 | mogadishu
# Processing Record 5 of Set 11 | klaksvik
# Processing Record 6 of Set 11 | ivanovka
# Processing Record 7 of Set 11 | toora-khem
# Processing Record 8 of Set 11 | shagonar
# Processing Record 9 of Set 11 | predivinsk
# Processing Record 10 of Set 11 | bida
# Processing Record 11 of Set 11 | tsiroanomandidy
# Processing Record 12 of Set 11 | homer
# Processing Record 13 of Set 11 | laguna
# Processing Record 14 of Set 11 | bulawayo
# Processing Record 15 of Set 11 | alugan
# Processing Record 16 of Set 11 | abu dhabi
# Processing Record 17 of Set 11 | tura
# Processing Record 18 of Set 11 | chibuto
# Processing Record 19 of Set 11 | baikunthpur
# Processing Record 20 of Set 11 | chanute
# Processing Record 21 of Set 11 | akureyri
# Processing Record 22 of Set 11 | naze
# Processing Record 23 of Set 11 | kolimvari
# City not found. Skipping...
# Processing Record 24 of Set 11 | road town
# Processing Record 25 of Set 11 | slave lake
# Processing Record 26 of Set 11 | umm lajj
# Processing Record 27 of Set 11 | sao filipe
# Processing Record 28 of Set 11 | kangaatsiaq
# Processing Record 29 of Set 11 | ankpa
# Processing Record 30 of Set 11 | ponta delgada
# Processing Record 31 of Set 11 | sorong
# Processing Record 32 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 11 | ferrol
# Processing Record 34 of Set 11 | half moon bay
# Processing Record 35 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 36 of Set 11 | ayan
# Processing Record 37 of Set 11 | northam
# Processing Record 38 of Set 11 | voyvozh
# Processing Record 39 of Set 11 | kudahuvadhoo
# Processing Record 40 of Set 11 | uchana
# Processing Record 41 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 11 | goianesia
# Processing Record 43 of Set 11 | karema
# Processing Record 44 of Set 11 | itoigawa
# Processing Record 45 of Set 11 | longyearbyen
# Processing Record 46 of Set 11 | at-bashi
# Processing Record 47 of Set 11 | roebourne
# Processing Record 48 of Set 11 | magan
# Processing Record 49 of Set 11 | bam
# Processing Record 50 of Set 11 | nalut
# Processing Record 1 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 12 | naregal
# Processing Record 3 of Set 12 | dukat
# Processing Record 4 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 5 of Set 12 | geraldton
# Processing Record 6 of Set 12 | darnah
# Processing Record 7 of Set 12 | yilan
# Processing Record 8 of Set 12 | mitsamiouli
# Processing Record 9 of Set 12 | pochutla
# Processing Record 10 of Set 12 | tatsinskaya
# City not found. Skipping...
# Processing Record 11 of Set 12 | cuitlahuac
# Processing Record 12 of Set 12 | warrensburg
# Processing Record 13 of Set 12 | vardo
# Processing Record 14 of Set 12 | sibu
# Processing Record 15 of Set 12 | saint-joseph
# Processing Record 16 of Set 12 | popondetta
# Processing Record 17 of Set 12 | nichinan
# Processing Record 18 of Set 12 | nisia floresta
# Processing Record 19 of Set 12 | krasnyy chikoy
# Processing Record 20 of Set 12 | machiques
# Processing Record 21 of Set 12 | seydi
# Processing Record 22 of Set 12 | buala
# Processing Record 23 of Set 12 | doka
# Processing Record 24 of Set 12 | coihaique
# Processing Record 25 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 26 of Set 12 | cessnock
# Processing Record 27 of Set 12 | dingle
# Processing Record 28 of Set 12 | sambava
# Processing Record 29 of Set 12 | totness
# Processing Record 30 of Set 12 | morant bay
# Processing Record 31 of Set 12 | pitkyaranta
# Processing Record 32 of Set 12 | the valley
# Processing Record 33 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 12 | malanje
# Processing Record 35 of Set 12 | antofagasta
# Processing Record 36 of Set 12 | pangkalanbuun
# Processing Record 37 of Set 12 | hofn
# Processing Record 38 of Set 12 | luwuk
# Processing Record 39 of Set 12 | nara
# Processing Record 40 of Set 12 | pangnirtung
# Processing Record 41 of Set 12 | nadym
# Processing Record 42 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 12 | rock sound
# Processing Record 44 of Set 12 | port-cartier
# Processing Record 45 of Set 12 | namatanai
# Processing Record 46 of Set 12 | ipixuna
# Processing Record 47 of Set 12 | college
# Processing Record 48 of Set 12 | tucurui
# Processing Record 49 of Set 12 | ibb
# Processing Record 50 of Set 12 | gravelbourg
# Processing Record 1 of Set 13 | ust-karsk
# Processing Record 2 of Set 13 | maple creek
# Processing Record 3 of Set 13 | bar harbor
# Processing Record 4 of Set 13 | mbandaka
# Processing Record 5 of Set 13 | malinovoye ozero
# Processing Record 6 of Set 13 | barra do garcas
# Processing Record 7 of Set 13 | calabozo
# Processing Record 8 of Set 13 | maues
# Processing Record 9 of Set 13 | ketchikan
# Processing Record 10 of Set 13 | moron
# Processing Record 11 of Set 13 | rawson
# Processing Record 12 of Set 13 | bang mun nak
# Processing Record 13 of Set 13 | tigil
# Processing Record 14 of Set 13 | srednekolymsk
# Processing Record 15 of Set 13 | imeni babushkina
# Processing Record 16 of Set 13 | benjamin hill
# Processing Record 17 of Set 13 | salalah
# Processing Record 18 of Set 13 | atambua
# Processing Record 19 of Set 13 | goderich
# Processing Record 20 of Set 13 | borogontsy
# Processing Record 21 of Set 13 | killarney
# Processing Record 22 of Set 13 | yar-sale
# Processing Record 23 of Set 13 | aconibe
# Processing Record 24 of Set 13 | port-gentil
# Processing Record 25 of Set 13 | manokwari
# Processing Record 26 of Set 13 | kurmanayevka
# Processing Record 27 of Set 13 | celestun
# Processing Record 28 of Set 13 | marzuq
# Processing Record 29 of Set 13 | thunder bay
# Processing Record 30 of Set 13 | santo domingo
# Processing Record 31 of Set 13 | turayf
# Processing Record 32 of Set 13 | dubbo
# Processing Record 33 of Set 13 | sola
# Processing Record 34 of Set 13 | qui nhon
# Processing Record 35 of Set 13 | seoul
# Processing Record 36 of Set 13 | ust-maya
# Processing Record 37 of Set 13 | jodhpur
# Processing Record 38 of Set 13 | maragogi
# Processing Record 39 of Set 13 | monrovia
# Processing Record 40 of Set 13 | westport
# Processing Record 41 of Set 13 | denizli
# Processing Record 42 of Set 13 | manta
# Processing Record 43 of Set 13 | inuvik
# Processing Record 44 of Set 13 | balashov
# Processing Record 45 of Set 13 | mineiros
# Processing Record 46 of Set 13 | rafraf
# Processing Record 47 of Set 13 | baijiantan
# Processing Record 48 of Set 13 | socorro
# Processing Record 49 of Set 13 | avdiyivka
# Processing Record 50 of Set 13 | puerto leguizamo
# Processing Record 1 of Set 14 | ziyang
# Processing Record 2 of Set 14 | georgetown
# Processing Record 3 of Set 14 | parras
# City not found. Skipping...
# Processing Record 4 of Set 14 | asfi
# Processing Record 5 of Set 14 | sandy bay
# Processing Record 6 of Set 14 | valentin gomez farias
# Processing Record 7 of Set 14 | kysyl-syr
# Processing Record 8 of Set 14 | jutai
# Processing Record 9 of Set 14 | ust-nera
# Processing Record 10 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 14 | kodinsk
# Processing Record 12 of Set 14 | camacha
# Processing Record 13 of Set 14 | kolpny
# Processing Record 14 of Set 14 | pareora
# Processing Record 15 of Set 14 | puerto escondido
# Processing Record 16 of Set 14 | ishinomaki
# Processing Record 17 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 14 | kattivakkam
# Processing Record 19 of Set 14 | ahmadpur sial
# Processing Record 20 of Set 14 | hobyo
# Processing Record 21 of Set 14 | duayaw nkwanta
# Processing Record 22 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 14 | vulcanesti
# Processing Record 24 of Set 14 | chulman
# Processing Record 25 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 26 of Set 14 | farafangana
# Processing Record 27 of Set 14 | panshi
# Processing Record 28 of Set 14 | azrow
# City not found. Skipping...
# Processing Record 29 of Set 14 | meiganga
# Processing Record 30 of Set 14 | witu
# Processing Record 31 of Set 14 | shambu
# Processing Record 32 of Set 14 | turukhansk
# Processing Record 33 of Set 14 | mabai
# Processing Record 34 of Set 14 | vanimo
# Processing Record 35 of Set 14 | karasjok
# Processing Record 36 of Set 14 | ipora
# Processing Record 37 of Set 14 | douglas
# Processing Record 38 of Set 14 | amapa
# Processing Record 39 of Set 14 | farah
# Processing Record 40 of Set 14 | waipawa
# Processing Record 41 of Set 14 | idlib
# Processing Record 42 of Set 14 | gornopravdinsk
# Processing Record 43 of Set 14 | whitecourt
# Processing Record 44 of Set 14 | diamantino
# Processing Record 45 of Set 14 | saint-georges
# Processing Record 46 of Set 14 | selkirk
# Processing Record 47 of Set 14 | paragould
# Processing Record 48 of Set 14 | syracuse
# Processing Record 49 of Set 14 | muromtsevo
# Processing Record 50 of Set 14 | kroya
# Processing Record 1 of Set 15 | tateyama
# Processing Record 2 of Set 15 | pontianak
# Processing Record 3 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 15 | fallon
# Processing Record 5 of Set 15 | brasileia
# Processing Record 6 of Set 15 | green valley
# Processing Record 7 of Set 15 | playa del carmen
# Processing Record 8 of Set 15 | grimmen
# Processing Record 9 of Set 15 | dinghai
# Processing Record 10 of Set 15 | kant
# Processing Record 11 of Set 15 | parasia
# Processing Record 12 of Set 15 | rocha
# Processing Record 13 of Set 15 | marsaxlokk
# Processing Record 14 of Set 15 | piranhas
# Processing Record 15 of Set 15 | sooke
# Processing Record 16 of Set 15 | pacific grove
# Processing Record 17 of Set 15 | asosa
# Processing Record 18 of Set 15 | korem
# Processing Record 19 of Set 15 | kostino
# Processing Record 20 of Set 15 | spencer
# Processing Record 21 of Set 15 | walvis bay
# Processing Record 22 of Set 15 | north bend
# Processing Record 23 of Set 15 | great falls
# Processing Record 24 of Set 15 | san cristobal
# Processing Record 25 of Set 15 | ormara
# Processing Record 26 of Set 15 | tarakan
# Processing Record 27 of Set 15 | rostaq
# City not found. Skipping...
# Processing Record 28 of Set 15 | san andres
# Processing Record 29 of Set 15 | raudeberg
# Processing Record 30 of Set 15 | tabou
# Processing Record 31 of Set 15 | ahuimanu
# Processing Record 32 of Set 15 | goulburn
# Processing Record 33 of Set 15 | wamba
# Processing Record 34 of Set 15 | chapais
# Processing Record 35 of Set 15 | vao
# Processing Record 36 of Set 15 | makakilo city
# Processing Record 37 of Set 15 | marion
# Processing Record 38 of Set 15 | arman
# Processing Record 39 of Set 15 | khani
# Processing Record 40 of Set 15 | beira
# Processing Record 41 of Set 15 | mantua
# Processing Record 42 of Set 15 | havre-saint-pierre
# Processing Record 43 of Set 15 | kavaratti
# Processing Record 44 of Set 15 | apaseo el alto
# Processing Record 45 of Set 15 | patu
# Processing Record 46 of Set 15 | bogo
# Processing Record 47 of Set 15 | linxia
# Processing Record 48 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 49 of Set 15 | ekpoma
# Processing Record 50 of Set 15 | boo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert array of dictionaries to panda DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Gobabis      NA -22.4500   18.9667     65.88        28           4
# 1          Ushuaia      AR -54.8000  -68.3000     40.66        60          40
# 2     San Patricio      US  28.0170  -97.5169     76.84        76          19
# 3      Banjarmasin      ID  -3.3244  114.5910     88.72        62          88
# 4            Tiksi      RU  71.6872  128.8694     -9.13        96         100
# 5            Kayes      ML  14.0000  -11.0000     73.20        16           0
# 6        Saskylakh      RU  71.9167  114.0833    -14.10        97          96
# 7         Cidreira      BR -30.1811  -50.2056     62.76        87           2
# 8           Hasaki      JP  35.7333  140.8333     72.28        50          24
# 9  Bambous Virieux      MU -20.3428   57.7575     75.22        68           8
#
#    Wind Speed Current Description
# 0       10.71           clear sky
# 1        9.22    scattered clouds
# 2        8.97          few clouds
# 3        0.94     overcast clouds
# 4        8.57     overcast clouds
# 5        1.41           clear sky
# 6        6.44     overcast clouds
# 7        3.56           clear sky
# 8       17.58          few clouds
# 9        9.57           clear sky

# %%
#Export Df as CSV file
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
